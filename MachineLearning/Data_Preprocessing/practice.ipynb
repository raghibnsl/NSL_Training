# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
# Out:
# /home/nsl53/anaconda3/envs/eda_/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# !{"pip install numpy==1.21.5"}
# Out:
# Requirement already satisfied: numpy==1.21.5 in /home/nsl53/anaconda3/envs/eda_/lib/python3.9/site-packages (1.21.5)

# %%
# !{"conda install scikit-learn"}
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/nsl53/anaconda3/envs/eda_
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     fftw-3.3.9                 |       h27cfd23_1         2.3 MB
#     libgfortran-ng-11.2.0      |       h00389a5_1          20 KB
#     libgfortran5-11.2.0        |       h1234567_1         2.0 MB
#     numpy-1.21.5               |   py39h6c91a56_3          10 KB
#     numpy-base-1.21.5          |   py39ha15fc14_3         4.9 MB
#     scikit-learn-1.1.1         |   py39h6a678d5_0         6.1 MB
#     scipy-1.7.3                |   py39h6c91a56_2        17.0 MB
#     ------------------------------------------------------------
#                                            Total:        32.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   fftw               pkgs/main/linux-64::fftw-3.3.9-h27cfd23_1
#   joblib             pkgs/main/noarch::joblib-1.1.0-pyhd3eb1b0_0
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-11.2.0-h00389a5_1
#   libgfortran5       pkgs/main/linux-64::libgfortran5-11.2.0-h1234567_1
#   scikit-learn       pkgs/main/linux-64::scikit-learn-1.1.1-py39h6a678d5_0
#   scipy              pkgs/main/linux-64::scipy-1.7.3-py39h6c91a56_2
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.2.0-pyh0d69192_0
#
# The following packages will be DOWNGRADED:
#
#   numpy                               1.23.1-py39h6c91a56_0 --> 1.21.5-py39h6c91a56_3
#   numpy-base                          1.23.1-py39ha15fc14_0 --> 1.21.5-py39ha15fc14_3
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
from sklearn.preprocessing import Normalizer
fig=plt.figure()
ax=fig.add_subplot(121,projection='3d')
ax1=fig.add_subplot(122,projection='3d')
df=pd.DataFrame({'x':np.random.randint(-80,80,1000),'y':np.random.randint(-100,100,1000),'z':np.random.randint(-150,150,1000)})
normalizer=Normalizer()
ax.scatter3D(df.x,df.y,df.z)
df_=normalizer.fit_transform(df)
ax1.scatter3D(df_[:,0],df_[:,1],df_[:,2])
